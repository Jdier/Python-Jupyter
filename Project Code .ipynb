# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
ds = pd.read_excel('P&P Fleet Data.xlsx')
ds.head(10)
# Out:
#    Equipment  Description of Technical Object License plate number  \
# 0   10022727                           2003.0               KUB443
# 1   10022728                           2001.0               JKP795
# 2   10022729                           2001.0               IYV828
# 3   10022730                           2003.0               KTP999
# 4   10022731                           2003.0               LFN720
# 5   10022732                           2003.0               KUC124
# 6   10022733                           2000.0               JBJ238
# 7   10022734                           2003.0               LEX425
# 8   10022735                           2003.0              LEU 665
# 9   10022736                           2003.0              LEX 404
#
#   Vehicle Type Planning plant   Manufacturer VIN  \
# 0      F_SEDAN           415A  2FAFP71W13X118927
# 1      F_SEDAN           415A  2FAFP71W81X174960
# 2      F_SEDAN           415A  2FAFP71W01X174953
# ...

# %%
sns.heatmap(ds.isnull())

# %%
plt.figure(figsize=(18,10))
sns.countplot(x='Model number',data=ds)

# %%
plt.figure(figsize=(18,10))
sns.countplot(x='Manufacturer of asset',y='Acquisition Value',data=ds)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-2eb670773d5e> in <module>
#       1 plt.figure(figsize=(18,10))
# ----> 2 sns.countplot(x='Manufacturer of asset',y='Acquisition Value',data=ds)
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
#    3543         y = x
#    3544     elif x is not None and y is not None:
# -> 3545         raise TypeError("Cannot pass values for both `x` and `y`")
#    3546     else:
#    3547         raise TypeError("Must pass values for either `x` or `y`")
#
# TypeError: Cannot pass values for both `x` and `y`

# %%
sns.heatmap(ds.isnull())

# %%
sns.factorplot(x ='Acquisition Value', y ='Model', 
               kind = 'strip', data = ds)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-1e9716292ab3> in <module>
# ----> 1 sns.factorplot(x ='Acquisition Value', y ='Model',
#       2                kind = 'strip', data = ds)
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in factorplot(*args, **kwargs)
#    3674     kwargs.setdefault("kind", "point")
#    3675
# -> 3676     return catplot(*args, **kwargs)
#    3677
#    3678
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in catplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, seed, order, hue_order, row_order, col_order, kind, height, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
#    3721     # facets to ensure representation of all data in the final plot
#    3722     p = _CategoricalPlotter()
# ...

# %%
ds['Acquisition Value'].max()
# Out:
# 27294.0

# %%
ds['Acquisition Value'].value_counts().head(1)
# Out:
# 19701.0    94
# Name: Acquisition Value, dtype: int64

# %%
sns.distplot(x='Acquisition Value', y='Model')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-7addb4363e20> in <module>
# ----> 1 sns.distplot(x='Acquisition Value', y='Model')
#
# TypeError: distplot() got an unexpected keyword argument 'x'

# %%
ds.isnull().sum().sum()
# Out:
# 862

# %%
ds.isnull().sum()
# Out:
# Equipment                               0
# Description of Technical Object        15
# License plate number                    4
# Vehicle Type                            0
# Planning plant                          0
# Manufacturer VIN                        3
# Functional Location                     0
# Unit Number                            36
# Acquisition Value                       3
# Manufacturer of asset                  23
# Model number                           41
# System status                           0
# Acquisition date                       83
# City                                    0
# Region                                  0
# Description of functional location      0
# Valid From                              0
# Validity end date                      42
# Street                                  0
# Address number                          0
# Postal Code                           369
# Asset                                  43
# ...

# %%
display(ds)
# Out:
#      Equipment  Description of Technical Object License plate number  \
# 0     10022727                           2003.0               KUB443
# 1     10022728                           2001.0               JKP795
# 2     10022729                           2001.0               IYV828
# 3     10022730                           2003.0               KTP999
# 4     10022731                           2003.0               LFN720
# ..         ...                              ...                  ...
# 642   10025578                           2019.0               727DER
# 643   10025579                           2019.0               728DER
# 644   10025580                           2019.0               724DER
# 645   10025581                           2019.0               779DER
# 646   10025590                           2019.0               670DER
#
#     Vehicle Type Planning plant   Manufacturer VIN  \
# 0        F_SEDAN           415A  2FAFP71W13X118927
# ...

# %%
ds.drop(['Equipment'], axis=1, inplace=True)

# %%
ds.drop(['Planning plant'], axis=1, inplace=True)

# %%
ds.drop(['Functional Location'], axis=1, inplace=True)

# %%
ds.drop(['Description of functional location'], axis=1, inplace=True)

# %%
ds.drop(['Address number'], axis=1, inplace=True)

# %%
ds.drop(['Postal Code'], axis=1, inplace=True)

# %%
ds.drop(['Asset'], axis=1, inplace=True)

# %%
ds.drop(['Cost Center'], axis=1, inplace=True)

# %%
ds.drop(['Primary Counter Unit'], axis=1, inplace=True)

# %%
display(ds)
# Out:
#      Description of Technical Object License plate number Vehicle Type  \
# 0                             2003.0               KUB443      F_SEDAN
# 1                             2001.0               JKP795      F_SEDAN
# 2                             2001.0               IYV828      F_SEDAN
# 3                             2003.0               KTP999      F_SEDAN
# 4                             2003.0               LFN720      F_SEDAN
# ..                               ...                  ...          ...
# 642                           2019.0               727DER      F_SEDAN
# 643                           2019.0               728DER      F_SEDAN
# 644                           2019.0               724DER      F_SEDAN
# 645                           2019.0               779DER      F_SEDAN
# 646                           2019.0               670DER      F_SEDAN
#
#       Manufacturer VIN  Unit Number  Acquisition Value Manufacturer of asset  \
# ...

# %%
ds.rename(columns = {"Manufacturer of asset": "Manufacturer"},  
          inplace = True)

# %%
ds.rename(columns = {"Description of Technical Object": "Year"},  
          inplace = True)

# %%
ds.rename(columns = {"Model number": "Model"},  
          inplace = True)

# %%
ds.rename(columns = {"Fuel Counter Reading": "Fuel Consumption"},  
          inplace = True)

# %%
ds.rename(columns = {"PrimaryCounterReadng": "Odometer Reading"},  
          inplace = True)

# %%
ds.rename(columns = {"Valid From": "Registration Start Date"},  
          inplace = True)

# %%
ds.rename(columns = {"Validity end date": "Registration End Date"},  
          inplace = True)

# %%
ds.isnull().sum().sum()
# Out:
# 378

# %%
ds.isnull().sum()
# Out:
# Year                       15
# License plate number        4
# Vehicle Type                0
# Manufacturer VIN            3
# Unit Number                36
# Acquisition Value           3
# Manufacturer               23
# Model                      41
# System status               0
# Acquisition date           83
# City                        0
# Region                      0
# Registration Start Date     0
# Registration End Date      42
# Street                      0
# Fuel Consumption           56
# Odometer Reading           72
# dtype: int64

# %%
ds['License plate number']
# Out:
# 0      KUB443
# 1      JKP795
# 2      IYV828
# 3      KTP999
# 4      LFN720
#         ...
# 642    727DER
# 643    728DER
# 644    724DER
# 645    779DER
# 646    670DER
# Name: License plate number, Length: 647, dtype: object

# %%
ds['License plate number'].fillna('No Plate Reported', inplace = True)

# %%
ds['Manufacturer VIN'].fillna('No VIN Reported', inplace = True)

# %%
ds['Unit Number'].fillna('No Unit Number Reported', inplace = True)

# %%
ds['Manufacturer'].fillna('No Manufacturer Reported', inplace = True)

# %%
ds['Model'].fillna('No Model Reported', inplace = True)

# %%
ds['Acquisition date'].fillna('No Acquisition date Reported', inplace = True)

# %%
ds['Registration End Date'].fillna('No Registration Ending Reported', inplace = True)

# %%
ds['Fuel Consumption'].fillna('0', inplace = True)

# %%
ds['Odometer Reading'].fillna('0', inplace = True)

# %%
ds.head()
# Out:
#      Year License plate number Vehicle Type   Manufacturer VIN Unit Number  \
# 0  2003.0               KUB443      F_SEDAN  2FAFP71W13X118927   UNIT #813
# 1  2001.0               JKP795      F_SEDAN  2FAFP71W81X174960         717
# 2  2001.0               IYV828      F_SEDAN  2FAFP71W01X174953         719
# 3  2003.0               KTP999      F_SEDAN  2FAFP71W93X118870         753
# 4  2003.0               LFN720      F_SEDAN  2FAFP71W03X118935         822
#
#    Acquisition Value Manufacturer           Model System status  \
# 0            20453.0         FORD  CROWN VICTORIA          INST
# 1            20400.0         FORD  CROWN VICTORIA          INST
# 2            20400.0         FORD  CROWN VICTORIA          INST
# 3            20207.0         FORD  CROWN VICTORIA          INST
# 4            20453.0         FORD  CROWN VICTORIA          INST
#
#       Acquisition date         City Region Registration Start Date  \
# ...

# %%
plt.figure(figsize=(18,10))
sns.countplot(x='Manufacturer',data=ds)

# %%
plt.figure(figsize=(18,10))
sns.barplot(x='City',y='Acquisition Value',data=ds)

# %%
plt.figure(figsize=(18,10))
sns.countplot(x='City',y='Acquisition Value',data=ds)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-67-3d14e7900be9> in <module>
#       1 plt.figure(figsize=(18,10))
# ----> 2 sns.countplot(x='City',y='Acquisition Value',data=ds)
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
#    3543         y = x
#    3544     elif x is not None and y is not None:
# -> 3545         raise TypeError("Cannot pass values for both `x` and `y`")
#    3546     else:
#    3547         raise TypeError("Must pass values for either `x` or `y`")
#
# TypeError: Cannot pass values for both `x` and `y`

# %%
sns.distplot(ds['Acquisition Value'])

# %%
ds.describe()['Acquisition Value']
# Out:
# count      644.000000
# mean     18953.158571
# std       2524.034335
# min      14216.000000
# 25%      17325.570000
# 50%      19701.000000
# 75%      20466.530000
# max      27294.000000
# Name: Acquisition Value, dtype: float64

# %%
with sns.axes_style('white'):
    fig = sns.factorplot("City", data=ds, aspect=2,
                       kind="count", color='steelblue', size=12)
    plt.xticks(rotation=45)
    fig.set_xticklabels(fig.get_xmajorticklabels(), fontsize = 18)
    fig.set_yticklabels(fig.get_ymajorticklabels(), fontsize = 18)
# Out:
# C:\Users\jeffery.dier\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\jeffery.dier\Anaconda3\lib\site-packages\seaborn\categorical.py:3672: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-69-adbbaa312ee5> in <module>
#       3                        kind="count", color='steelblue', size=12)
#       4     plt.xticks(rotation=45)
# ----> 5     fig.set_xticklabels(fig.get_xmajorticklabels(), fontsize = 18)
# ...

# %%
with sns.axes_style('white'):
    g = sns.factorplot("Manufacturer", data=ds, aspect=2,
                       kind="count", color='steelblue', size=9)

# %%
plt.figure(figsize=(18,10))
plt.xticks(rotation=45)
sns.countplot(x='City',data=ds,palette="magma")

# %%
sns.boxplot(x="Model",y="Odometer Reading",data=ds)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-71-2f9aa470a596> in <module>
# ----> 1 sns.boxplot(x="Model",y="Odometer Reading",data=ds)
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2239     kwargs.update(dict(whis=whis))
#    2240
# -> 2241     plotter.plot(ax, kwargs)
#    2242     return ax
#    2243
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in plot(self, ax, boxplot_kws)
#     537     def plot(self, ax, boxplot_kws):
#     538         """Make the plot."""
# --> 539         self.draw_boxplot(ax, boxplot_kws)
#     540         self.annotate_axes(ax)
#     541         if self.orient == "h":
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in draw_boxplot(self, ax, kws)
# ...

# %%
plt.figure(figsize=(18,10))
sns.barplot(x='City',y='Odometer Reading',data=ds)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-72-82795453df9e> in <module>
#       1 plt.figure(figsize=(18,10))
# ----> 2 sns.barplot(x='City',y='Odometer Reading',data=ds)
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3142             ax=None, **kwargs):
#    3143
# -> 3144     plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    3145                           estimator, ci, n_boot, units, seed,
#    3146                           orient, color, palette, saturation,
#
# ...

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 647 entries, 0 to 646
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Year                     632 non-null    float64
#  1   License plate number     647 non-null    object
#  2   Vehicle Type             647 non-null    object
#  3   Manufacturer VIN         647 non-null    object
#  4   Unit Number              647 non-null    object
#  5   Acquisition Value        644 non-null    float64
#  6   Manufacturer             647 non-null    object
#  7   Model                    647 non-null    object
#  8   System status            647 non-null    object
#  9   Acquisition date         647 non-null    object
#  10  City                     647 non-null    object
#  11  Region                   647 non-null    object
#  12  Registration Start Date  647 non-null    datetime64[ns]
#  13  Registration End Date    647 non-null    object
# ...

# %%
ds["Fuel Consumption"] = ds["Fuel Consumption"].astype(str).astype(float)

# %%
ds["Odometer Reading"] = ds["Odometer Reading"].astype(str).astype(float)

# %%
plt.figure(figsize=(20,10))
plt.xticks(rotation=45)
sns.barplot(x='City',y='Odometer Reading',data=ds,palette="winter_r")

# %%
plt.figure(figsize=(20,10))
plt.xticks(rotation=45)
sns.set(font_scale = 1)
sns.stripplot(x='City',y='Odometer Reading',data=ds,palette="winter_r")

# %%
plt.figure(figsize=(20,10))
plt.xticks(rotation=45)
sns.barplot(x='City',y='Fuel Consumption',data=ds,palette="mako")

# %%
plt.figure(figsize=(20,10))
plt.xticks(rotation=45)
sns.stripplot(x='City',y='Fuel Consumption',data=ds,palette="mako")

# %%
plt.figure(figsize=(25,10))
sns.swarmplot(x="City",y="Odometer Reading",data=ds)

# %%
plt.figure(figsize=(25,10))
sns.countplot(x="City",y="Odometer Reading",data=ds)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-81-d0b207f9ba20> in <module>
#       1 plt.figure(figsize=(25,10))
# ----> 2 sns.countplot(x="City",y="Odometer Reading",data=ds)
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
#    3543         y = x
#    3544     elif x is not None and y is not None:
# -> 3545         raise TypeError("Cannot pass values for both `x` and `y`")
#    3546     else:
#    3547         raise TypeError("Must pass values for either `x` or `y`")
#
# TypeError: Cannot pass values for both `x` and `y`

# %%
plt.figure(figsize=(20,10))
plt.xticks(rotation=45)
sns.barplot(x="City",y="Odometer Reading",data=ds)

# %%
plt.figure(figsize=(25,10))
sns.swarmplot(x="City",y="year",data=ds)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-83-d6617f9bdf82> in <module>
#       1 plt.figure(figsize=(25,10))
# ----> 2 sns.swarmplot(x="City",y="year",data=ds)
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in swarmplot(x, y, hue, data, order, hue_order, dodge, orient, color, palette, size, edgecolor, linewidth, ax, **kwargs)
#    2971         warnings.warn(msg, UserWarning)
#    2972
# -> 2973     plotter = _SwarmPlotter(x, y, hue, data, order, hue_order,
#    2974                             dodge, orient, color, palette)
#    2975     if ax is None:
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, dodge, orient, color, palette)
#    1199                  dodge, orient, color, palette):
#    1200         """Initialize the plotter."""
# ...

# %%
plt.figure(figsize=(25,10))
sns.distplot(x="Model",y="Year",data=ds)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-84-20838de07760> in <module>
#       1 plt.figure(figsize=(25,10))
# ----> 2 sns.distplot(x="Model",y="Year",data=ds)
#
# TypeError: distplot() got an unexpected keyword argument 'x'

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 647 entries, 0 to 646
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Year                     632 non-null    float64
#  1   License plate number     647 non-null    object
#  2   Vehicle Type             647 non-null    object
#  3   Manufacturer VIN         647 non-null    object
#  4   Unit Number              647 non-null    object
#  5   Acquisition Value        644 non-null    float64
#  6   Manufacturer             647 non-null    object
#  7   Model                    647 non-null    object
#  8   System status            647 non-null    object
#  9   Acquisition date         647 non-null    object
#  10  City                     647 non-null    object
#  11  Region                   647 non-null    object
#  12  Registration Start Date  647 non-null    datetime64[ns]
#  13  Registration End Date    647 non-null    object
# ...

# %%
plt.figure(figsize=(15,10))
sns.set_style("darkgrid")
sns.set_style("ticks")
plt.xticks(rotation=60)
sns.countplot(x = 'Year', data = ds, hue = 'City')

# %%
ds[ds['City'] == 'HARVEY'].groupby('Year').count()['City'].plot()

# %%
ds[ds['City'] == 'CLINTON'].groupby('Year').count()['City'].plot()

# %%
ds['City'].value_counts()
# Out:
# HARVEY          66
# BATON ROUGE     53
# NEW ORLEANS     51
# SHREVEPORT      45
# COVINGTON       43
# MONROE          40
# ALEXANDRIA      40
# LAFAYETTE       38
# THIBODAUX       33
# LAKE CHARLES    32
# AMITE           29
# NEW IBERIA      26
# KENNER          23
# NATCHITOCHES    21
# VILLE PLATTE    20
# PORT ALLEN      20
# ST. JAMES       18
# MINDEN          17
# TALLULAH        14
# LEESVILLE       11
# CLINTON          7
# Name: City, dtype: int64

# %%
plt.figure(figsize=(15,10))
sns.set_style("darkgrid")
sns.set_style("ticks")
plt.xticks(rotation=45)
sns.factorplot(x = 'Year', data = ds, hue = 'City')
# Out:
# C:\Users\jeffery.dier\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-90-1bf8387091f9> in <module>
#       3 sns.set_style("ticks")
#       4 plt.xticks(rotation=45)
# ----> 5 sns.factorplot(x = 'Year', data = ds, hue = 'City')
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in factorplot(*args, **kwargs)
#    3674     kwargs.setdefault("kind", "point")
#    3675
# -> 3676     return catplot(*args, **kwargs)
#    3677
#    3678
#
# ...

# %%
plt.figure(figsize=(15,10))
plt.xticks(rotation=45)
sns.countplot(x='Model',data=ds,palette="twilight")

# %%
plt.figure(figsize=(20,10))
plt.xticks(rotation=60)
sns.countplot(x='Acquisition Value',data=ds,palette="magma")

# %%
ds['Model'].value_counts()
# Out:
# CHARGER              150
# FUSION               108
# IMPALA               107
# CROWN VICTORIA        89
# AVENGER               44
# TAURUS                43
# No Model Reported     41
# DURANGO               27
# IMPALA LIMITED        16
# 1500 CLASSIC          13
# EXPLORER               7
# CARAVAN                1
# TERRAIN                1
# Name: Model, dtype: int64

# %%
ds.head()
# Out:
#      Year License plate number Vehicle Type   Manufacturer VIN Unit Number  \
# 0  2003.0               KUB443      F_SEDAN  2FAFP71W13X118927   UNIT #813
# 1  2001.0               JKP795      F_SEDAN  2FAFP71W81X174960         717
# 2  2001.0               IYV828      F_SEDAN  2FAFP71W01X174953         719
# 3  2003.0               KTP999      F_SEDAN  2FAFP71W93X118870         753
# 4  2003.0               LFN720      F_SEDAN  2FAFP71W03X118935         822
#
#    Acquisition Value Manufacturer           Model System status  \
# 0            20453.0         FORD  CROWN VICTORIA          INST
# 1            20400.0         FORD  CROWN VICTORIA          INST
# 2            20400.0         FORD  CROWN VICTORIA          INST
# 3            20207.0         FORD  CROWN VICTORIA          INST
# 4            20453.0         FORD  CROWN VICTORIA          INST
#
#       Acquisition date         City Region Registration Start Date  \
# ...

# %%
ds['Manufacturer'].value_counts()
# Out:
# DODGE                       253
# FORD                        247
# CHEVROLET                   123
# No Manufacturer Reported     23
# GMC                           1
# Name: Manufacturer, dtype: int64

# %%
ds['Acquisition Value'].sum()
# Out:
# 12205834.120000001

# %%
plt.figure(figsize=(18,10))
sns.countplot(x='Manufacturer',data=ds,palette="Dark2")

# %%
ds.describe()['Acquisition Value']
# Out:
# count      644.000000
# mean     18953.158571
# std       2524.034335
# min      14216.000000
# 25%      17325.570000
# 50%      19701.000000
# 75%      20466.530000
# max      27294.000000
# Name: Acquisition Value, dtype: float64

# %%
plt.figure(figsize=(20,10))
plt.xticks(rotation=45)
sns.barplot(x='Model',y='Fuel Consumption',data=ds,palette="coolwarm")

# %%
plt.figure(figsize=(20,10))
plt.xticks(rotation=45)
sns.violinplot(x='Model',y='Fuel Consumption',data=ds,palette="coolwarm")

# %%
plt.figure(figsize=(15,10))
sns.set_style("darkgrid")
sns.set_style("ticks")
plt.xticks(rotation=60)
sns.countplot(x = 'Model', data = ds, hue = 'Acquisition Value')

# %%
plt.figure(figsize=(20,10))
plt.xticks(rotation=45)
sns.barplot(x='Model',y='Odometer Reading',data=ds,palette="cubehelix")

# %%
plt.figure(figsize=(20,10))
plt.xticks(rotation=45)
sns.boxplot(x='Model',y='Odometer Reading',data=ds,palette="cubehelix")

# %%
plt.figure(figsize=(20,10))
plt.xticks(rotation=45)
sns.barplot(x='Model',y='Acquisition Value',data=ds,palette="afmhot")

# %%
sns.pairplot(data=ds)

# %%
plt.figure(figsize=(20,10))
plt.xticks(rotation=45)
sns.barplot(x='City',y='Year',data=ds,palette="afmhot")

# %%
plt.figure(figsize=(20,10))
plt.xticks(rotation=45)
sns.barplot(x='City',y='Acquisition Value',data=ds,palette="gnuplot")
